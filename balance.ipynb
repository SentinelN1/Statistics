# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
arr = np.random.normal(size=10)

# %%
sum_1 = np.sum(arr[0:5])
sum_2 = np.sum(arr[5:10])
sum_1, sum_2
# Out:
# (1.3199336589564714, -1.6314240445283672)

# %%
plt.hist(diff, density=True, bins=100)
plt.grid()
plt.show()
